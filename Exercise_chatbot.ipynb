# %% [markdown]
# # Chatbot setup

# %%
# !pip install openai
# !pip install python-dotenv

# %%
from openai import OpenAI
from google.colab import userdata
OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')

# %%
client = OpenAI(
    # This is the default and can be omitted
    api_key=OPENAI_API_KEY,
)

def get_completion(prompt, model="gpt-3.5-turbo", temperature=1):
    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=temperature,
    )
    return response.choices[0].message.content


def get_completion_from_messages(message, model="gpt-3.5-turbo", temperature=1):
    response = client.chat.completions.create(
        model=model,
        messages=message,
        temperature=temperature,
    )
    return response.choices[0].message.content

# %%
messages =  [
{'role':'system', 'content':'You are friendly chatbot.'},
{'role':'user', 'content':'Hi, my name is Kiven'},
{'role':'assistant', 'content': "Hi Isa! It's nice to meet you. \
Is there anything I can help you with today?"},
{'role':'user', 'content':'Yes, you can remind me, What is my name?'}  ]
response = get_completion_from_messages(messages, temperature=1)
print(response)
# Out:
# Your name is Kiven.

# %%
def collect_messages(_):
    prompt = inp.value_input
    inp.value = ''
    context.append({'role':'user', 'content':f"{prompt}"})
    response = get_completion_from_messages(context)
    context.append({'role':'assistant', 'content':f"{response}"})
    panels.append(
        pn.Row('User:', pn.pane.Markdown(prompt, width=600)))
    panels.append(
        pn.Row('Assistant:', pn.pane.Markdown(response, width=600, styles={'background-color': '#F6F6F6'})))

    return pn.Column(*panels)

# %% [markdown]
# # McDonald's order chatbot

# %%
import panel as pn
pn.extension()
def collect_messages(_):
    prompt = inp.value_input
    inp.value = ''
    context.append({'role':'user', 'content':f"{prompt}"})
    response = get_completion_from_messages(context)
    context.append({'role':'assistant', 'content':f"{response}"})
    panels.append(
        pn.Row('User:', pn.pane.Markdown(prompt, width=600)))
    panels.append(
        pn.Row('Assistant:', pn.pane.Markdown(response, width=600, styles={'background-color': '#F6F6F6'})))

    return pn.Column(*panels)

temperature = 1

panels = []

context = [ {'role':'system', 'content':"""
You are OrderBot, an automated service to collect orders for McDonald's. \
You first greet the customer, then collects the order, \
and then asks if it's a pickup or delivery. \
You wait to collect the entire order, then summarize it and check for a final \
time if the customer wants to add anything else. \
If it's a delivery, you ask for an address. \
Finally you collect the payment.\
Make sure to clarify all options, extras and sizes to uniquely \
identify the item from the menu.\
You respond in a short, very conversational friendly style. \
The menu includes \
Big tasty burger   10.00, 7.00 \
Homestyle burger   9.25, 6.50 \
Bigmac burger   8.75, 6.75 \
fries 4.50, 3.50 \
Chicken salad 6.25 \
Toppings: \
extra cheese 2.00, \
canadian bacon 3.50 \
AI sauce 1.50 \
peppers 1.00 \
Drinks: \
coke 3.00, 2.00, 1.00 \
sprite 3.00, 2.00, 1.00 \
bottled water 5.00 \
"""} ]  # accumulate messages


inp = pn.widgets.TextInput(value="Hi", placeholder='Enter text here…')
button_conversation = pn.widgets.Button(name="Chat!")

interactive_conversation = pn.bind(collect_messages, button_conversation)

dashboard = pn.Column(
    inp,
    pn.Row(button_conversation),
    pn.panel(interactive_conversation, loading_indicator=True, height=300),
)

dashboard
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='3f8876b6-16b0-456c-b319-b2318dc1fbea'>
#   <div id="ec22eb46-86c8-48bf-98fe-e697ed061d25" data-root-id="3f8876b6-16b0-456c-b319-b2318dc1fbea" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# # GOT tv serie

# %%
import panel as pn
pn.extension()
def collect_messages(_):
    prompt = inp.value_input
    inp.value = ''
    context.append({'role':'user', 'content':f"{prompt}"})
    response = get_completion_from_messages(context)
    context.append({'role':'assistant', 'content':f"{response}"})
    panels.append(
        pn.Row('User:', pn.pane.Markdown(prompt, width=600)))
    panels.append(
        pn.Row('Assistant:', pn.pane.Markdown(response, width=600, styles={'background-color': '#F6F6F6'})))

    return pn.Column(*panels)

temperature = 1

panels = []

context = [
    {
        'role': 'system',
        'content': """
Game of Thrones is a high-fantasy drama television series. The show is set in the fictional continent of Westeros,
where powerful families and noble houses fight for control of the Seven Kingdoms.

The story follows the power struggles, alliances, and conflicts between the major houses, as well as the looming threat of an ancient evil force known as the White Walkers beyond the northern borders of the kingdoms.
The series features a large ensemble cast of characters, each with their own ambitions, secrets, and personal struggles.

Key themes of the show include the nature of power, the consequences of ambition, the complexities of morality, and the struggles between duty and personal desires.
The series is renowned for its complex political intrigue, shocking plot twists, and graphic depictions of violence and sexuality.

Game of Thrones was a massive critical and commercial success, running for 8 seasons from 2011 to 2019.
It is widely regarded as one of the most popular and influential television series of the 21st century.
"""
    }
]



inp = pn.widgets.TextInput(value="Hi", placeholder='Enter text here…')
button_conversation = pn.widgets.Button(name="Chat!")

interactive_conversation = pn.bind(collect_messages, button_conversation)

dashboard = pn.Column(
    inp,
    pn.Row(button_conversation),
    pn.panel(interactive_conversation, loading_indicator=True, height=300),
)

dashboard
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='9e7a2293-46f3-4d20-9057-d2a79c93af73'>
#   <div id="aacaa2c2-0231-4ffb-9d00-00324692c98f" data-root-id="9e7a2293-46f3-4d20-9057-d2a79c93af73" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# # Ice cream salon

# %%
import panel as pn
pn.extension()
def collect_messages(_):
    prompt = inp.value_input
    inp.value = ''
    context.append({'role':'user', 'content':f"{prompt}"})
    response = get_completion_from_messages(context)
    context.append({'role':'assistant', 'content':f"{response}"})
    panels.append(
        pn.Row('User:', pn.pane.Markdown(prompt, width=600)))
    panels.append(
        pn.Row('Assistant:', pn.pane.Markdown(response, width=600, styles={'background-color': '#F6F6F6'})))

    return pn.Column(*panels)

temperature = 1

panels = []

context = [
    {
        'role': 'system',
        'content': """
Hello, welcome to our ice cream parlor! How can I assist you with your order today?

We have a wide selection of delicious ice cream flavors, including:
- Vanilla
- Chocolate
- Strawberry
- Mint Chocolate Chip
- Salted Caramel
- Cookies and Cream

And for toppings, we have:
- Caramel sauce
- Chocolate sauce
- Sprinkles
- Waffle cone pieces
- Whipped cream

Would you like a single scoop or a double scoop? And which flavor(s) would you like?

Once you've selected your ice cream, what toppings would you like? You can choose up to 3 toppings.

Okay, great! What table number are you sitting at? And would you like to pay with a card or online?

Processing your payment now... Your order will be ready shortly. Please let me know if you need anything else!
"""
    }
]




inp = pn.widgets.TextInput(value="Hi", placeholder='Enter text here…')
button_conversation = pn.widgets.Button(name="Chat!")

interactive_conversation = pn.bind(collect_messages, button_conversation)

dashboard = pn.Column(
    inp,
    pn.Row(button_conversation),
    pn.panel(interactive_conversation, loading_indicator=True, height=300),
)

dashboard
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='b3b36cb5-439a-4711-b2eb-748d7342c1ff'>
#   <div id="c1505688-ae9d-4c5b-812d-3e84e5c7493a" data-root-id="b3b36cb5-439a-4711-b2eb-748d7342c1ff" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...
